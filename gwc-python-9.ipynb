# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Datatypes

# %%
# String - a sequence of characters
# Integer  - a whole number, positive or negative
# Float - decimals, positive or negative
# Boolean  - True or False

# %%
# print statements
print("Hello World")
print(5)
print(55.5)
print(True)

# %%
# declare variables

# %% [markdown]
# <br><br><br>
#
# # WHAT IS THE OUTPUT?
#
# <br>

# %%
# myString = "Hello World"
print(myString + " I'm Bernice")

# %%
print(myString + 6)

# %% [markdown]
# <br> <br><br>
#
#
# ## MATH OPERATORS
# #   +   -   /   //  %

# %%
# Addition           +
# Subtraction        - 
# Division           / 
# Integer Division   // 
# Modulo             %

# %%
add = 1 + 1
print(add)

# %%
subtract = 2309 - 213
print(subtract)

# %%
divide = 9/-6
print(divide)

# %%
divideInteger = 9//-6
print(divideInteger)

# %%
#casting

# %%
modulo = 12 % 8

# 12/8 = 1
# 12 - (8*1) = 4

print(modulo)

# %% [markdown]
# <br><br>
#
# # Boolean Expressions
#
# ## Is 2 greater than  1? Are you in high school? Is the temperature hot outside?
#
# ![image-3.png](attachment:image-3.png)
#
# ## Even if its easy to figure out we can have the computer check that for us.
#
# <br><br>

# %%
greaterThanOne = 2 > 1
print(greaterThanOne)
# Out:
# True

# %%
grade = 12

HighSchool = grade > 8 and grade < 13

print(HighSchool)

# %%
temp = 80
tooHot = temp >= 100
perfectTemp = temp == 70


print("Too Hot: ", tooHot, "\nPerfect Temperature: ", perfectTemp)

# %%
sunny = True
umbrella = not sunny

print("I need an umbrella: ", umbrella)

# %% [markdown]
# # Control Structure - Selection with If Statements <br> <br>
#
# ![image-2.png](attachment:image-2.png)
# <br>
#
# ### Is it ok to go on a walk in San Francisco?
# ![image-4.png](attachment:image-4.png)

# %%
# if the sky is clear, print "yes! go out and enjoy the day" 
# If it's not clear, print "no, you should be used to this by now"

# %%
# check the air quality
# if the air quality is less than 150, print "yes, unless you are particularly sensitive"

# %% [markdown]
# ## Does any one have any questions at all?
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# # What if I wanted to check if I could go on a walk every day?

# %% [markdown]
# ## I could just repeatedly type out the code over and over again?
# ![image-5.png](attachment:image-5.png)
# ## yea... no.

# %% [markdown]
# # I want to reuse code! This makes it easier for me to create and for others to read! <br>
#
# ![image-2.png](attachment:image-2.png)
# <br>

# %% [markdown]
# # FUNCTIONS

# %% [markdown]
# # A function is a block of organized, reusable code that is used to perform a single, related action
#
# ![image-2.png](attachment:image-2.png)
#
# <br><br>

# %%
# What if we want to use that code every day to check if we should go out???
# parameters are where you create variables

# %%
# input - is the sky clear?
# input - what is the air quality?

# %% [markdown]
# # Writing Your Own Code

# %%
def add(one, two):
    return one + two;

def sub(one, two):
    return one - two;

print("Add or Subtract Two Numbers")

first = float(input("What is the first number: "))
second = float(input("What is the second number: "))
operator = input("What operator would you like to use? + or -: ")

if operator == "+":
    ans = add(first, second)
else:
    ans = sub(first, second)
    
print("The result is", ans)
